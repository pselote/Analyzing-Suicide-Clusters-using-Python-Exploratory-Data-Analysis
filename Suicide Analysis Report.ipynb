# %% [markdown]
# #  Suicide Analysis using Python

# %% [markdown]
# # Import labraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load the dataset

# %%
df= pd.read_csv("C:/Users/Pritam\Desktop/DBA/Analysis files/sucideData.csv")
df
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# ...           ...   ...     ...          ...          ...         ...
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %% [markdown]
# # Shape of the data

# %%
df.shape
# Out:
# (27820, 12)

# %% [markdown]
# # Size of the Data

# %%
df.size
# Out:
# 333840

# %% [markdown]
# # Top 10 records

# %%
df.head(10)
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
# 5  Albania  1987  female    75+ years            1       35600
# 6  Albania  1987  female  35-54 years            6      278800
# 7  Albania  1987  female  25-34 years            4      257200
# 8  Albania  1987    male  55-74 years            1      137500
# 9  Albania  1987  female   5-14 years            0      311000
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# ...

# %% [markdown]
# # Bottom 10 records

# %%
df.tail(10)
# Out:
#           country  year     sex          age  suicides_no  population  \
# 27810  Uzbekistan  2014  female  15-24 years          347     2992817
# 27811  Uzbekistan  2014    male  55-74 years          144     1271111
# 27812  Uzbekistan  2014    male  15-24 years          347     3126905
# 27813  Uzbekistan  2014    male    75+ years           17      224995
# 27814  Uzbekistan  2014  female  25-34 years          162     2735238
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27816  Uzbekistan  2014  female    75+ years            9      348465
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
# 27819  Uzbekistan  2014  female  55-74 years           21     1438935
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# 27810              11.59  Uzbekistan2014         0.675     63,067,077,179
# ...

# %% [markdown]
# # Number of colomns

# %%
df.columns
# Out:
# Index(['country', 'year', 'sex', 'age', 'suicides_no', 'population',
#        'suicides/100k pop', 'country-year', 'HDI for year',
#        ' gdp_for_year ($) ', 'gdp_per_capita ($)', 'generation'],
#       dtype='object')

# %% [markdown]
# # Info about Data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27820 entries, 0 to 27819
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country             27820 non-null  object
#  1   year                27820 non-null  int64
#  2   sex                 27820 non-null  object
#  3   age                 27820 non-null  object
#  4   suicides_no         27820 non-null  int64
#  5   population          27820 non-null  int64
#  6   suicides/100k pop   27820 non-null  float64
#  7   country-year        27820 non-null  object
#  8   HDI for year        8364 non-null   float64
#  9    gdp_for_year ($)   27820 non-null  object
#  10  gdp_per_capita ($)  27820 non-null  int64
#  11  generation          27820 non-null  object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 2.5+ MB

# %% [markdown]
# #### Missing Value Detection by Features

# %%
df.isnull().sum()
# Out:
# country                   0
# year                      0
# sex                       0
# age                       0
# suicides_no               0
# population                0
# suicides/100k pop         0
# country-year              0
# HDI for year          19456
#  gdp_for_year ($)         0
# gdp_per_capita ($)        0
# generation                0
# dtype: int64

# %% [markdown]
# #  DATA Analysis

# %% [markdown]
# # 1. Query to extraxt data on basis of gender

# %% [markdown]
# ### * Total number of sucide cases by gender

# %%
df.groupby("sex")["suicides_no"].sum()
# Out:
# sex
# female    1559510
# male      5188910
# Name: suicides_no, dtype: int64

# %% [markdown]
# ### * Average suicide rates by gender

# %%
df.groupby("sex")["suicides/100k pop"].mean()
# Out:
# sex
# female     5.392866
# male      20.239329
# Name: suicides/100k pop, dtype: float64

# %% [markdown]
# ### * Suicide Numbers by Gender

# %%
plt.figure(figsize=(8,5))
sns.barplot(x = "sex", 
            y = "suicides_no", 
            data = df)
plt.xlabel('Gender')
plt.ylabel('Number of Suicide')
plt.title('Suicide Numbers by Gender')
plt.show()

# %% [markdown]
# * Clearly we can see that sucide rate of male are more than female.

# %% [markdown]
# # 2. Visualize the ranking of the countries by the no. of suicides

# %% [markdown]
# ### * Average numbers of suicide by country
# ### * The countries with the highest numbers of suicide are below

# %%
df.groupby("country", as_index = False)["suicides_no"].mean().sort_values(by="suicides_no",ascending = False).head()
# Out:
#                country  suicides_no
# 75  Russian Federation  3733.771605
# 98       United States  2779.604839
# 46               Japan  2169.091398
# 95             Ukraine   952.232143
# 35             Germany   933.532051

# %% [markdown]
# ### Bar Graph for Suicide Numbers by Countries

# %%
countrySN = df.groupby("country", as_index = False)["suicides_no"].mean().sort_values(by="suicides_no",ascending = False)
plt.figure(figsize=(6,15))
sns.barplot(x = "suicides_no", 
            y = "country", 
            data = countrySN)
plt.xlabel('Number of Suicide')
plt.ylabel('Country')
plt.title('Suicide Numbers by Countries')
plt.show()

# %% [markdown]
# * Clearly we can see that Russian Federation has heighest number of sucide.

# %% [markdown]
# # 3. Which year highest number of sucide

# %% [markdown]
# ### * Average numbers of suicide by year

# %%
df.groupby("year", as_index = False)["suicides_no"].mean().sort_values(by="suicides_no",ascending = False)
# Out:
#     year  suicides_no
# 9   1994   284.390931
# 8   1993   284.057692
# 30  2015   273.709677
# 7   1992   271.119231
# 11  1996   267.018398
# 13  1998   263.281646
# 12  1997   260.546537
# 10  1995   260.196581
# 6   1991   257.838542
# 14  1999   257.147590
# 4   1989   256.801282
# 5   1990   251.772135
# 17  2002   248.154070
# 18  2003   248.138566
# 15  2000   247.899225
# 19  2004   238.949405
# 29  2014   238.230769
# 16  2001   237.359848
# 27  2012   236.790123
# 20  2005   232.514881
# 28  2013   232.498958
# 23  2008   230.830392
# 26  2011   229.151163
# 21  2006   228.785294
# 24  2009   227.984082
# 22  2007   226.170543
# 25  2010   226.043561
# 1   1986   209.496528
# 3   1988   205.826531
# 0   1985   201.498264
# 2   1987   195.743827
# 31  2016    97.518750

# %% [markdown]
# ### * Pointplot for Average Suicide Numbers by Years

# %%
yearMeanSN = df.groupby("year", as_index = False)["suicides_no"].mean()
plt.figure(figsize=(15,6))
sns.pointplot(x = "year", 
              y = "suicides_no", 
              data = yearMeanSN)
plt.xlabel('Year')
plt.ylabel('Average Number of Suicide')
plt.title('Average Suicide Numbers by Years')
plt.show()

# %% [markdown]
# * We can clearly see that year 1994 has heighest number of sucides rate.

# %% [markdown]
# ###  * Query to extraxt data of the year 2014

# %%
df_2014=df.loc[(df['year']==2014)]
df_2014
# Out:
#                    country  year     sex          age  suicides_no  \
# 564    Antigua and Barbuda  2014  female  15-24 years            0
# 565    Antigua and Barbuda  2014  female  25-34 years            0
# 566    Antigua and Barbuda  2014  female  35-54 years            0
# 567    Antigua and Barbuda  2014  female   5-14 years            0
# 568    Antigua and Barbuda  2014  female  55-74 years            0
# ...                    ...   ...     ...          ...          ...
# 27815           Uzbekistan  2014  female  35-54 years          107
# 27816           Uzbekistan  2014  female    75+ years            9
# 27817           Uzbekistan  2014    male   5-14 years           60
# 27818           Uzbekistan  2014  female   5-14 years           44
# 27819           Uzbekistan  2014  female  55-74 years           21
#
#        population  suicides/100k pop             country-year  HDI for year  \
# 564          8537               0.00  Antigua and Barbuda2014         0.783
# ...

# %% [markdown]
# # 4. Which Age group has heighest number of suicides rate.

# %% [markdown]
# ### * Average suicide rates by age

# %%
df.groupby("age", as_index = False)["suicides/100k pop"].mean().sort_values(by="suicides/100k pop",ascending = False)
# Out:
#            age  suicides/100k pop
# 5    75+ years          23.955409
# 4  55-74 years          16.155579
# 2  35-54 years          14.947441
# 1  25-34 years          12.186885
# 0  15-24 years           8.947154
# 3   5-14 years           0.620041

# %% [markdown]
# ### * Barplot for Suicide Numbers by Age Groups

# %%
ageDataSN = df.groupby("age", as_index = False)["suicides_no"].mean().sort_values(by="suicides_no",ascending = False)
plt.figure(figsize=(8,5))
sns.barplot(x = "age", 
            y = "suicides_no", 
            data = ageDataSN)
plt.xlabel('Age Group')
plt.ylabel('Number of Suicide')
plt.title('Suicide Numbers by Age Groups')
plt.show()

# %% [markdown]
# * Sucide rate between age group 35-54 are heighest.
# * Sucide rate between age group 5-14 are lowest.

# %% [markdown]
# # 5. Which generation has highest number of suicide rate

# %%
df["generation"].value_counts()
# Out:
# Generation X       6408
# Silent             6364
# Millenials         5844
# Boomers            4990
# G.I. Generation    2744
# Generation Z       1470
# Name: generation, dtype: int64

# %% [markdown]
# ### * Average suicide numbers by generation

# %%
df.groupby("generation", as_index = False)["suicides_no"].mean().sort_values(by="suicides_no",ascending = False)
# Out:
#         generation  suicides_no
# 0          Boomers   457.815230
# 5           Silent   279.972344
# 2     Generation X   239.201623
# 1  G.I. Generation   185.863338
# 4       Millenials   106.683607
# 3     Generation Z    10.820408

# %% [markdown]
# ### * Barplot for Suicide Numbers by Generations

# %%
genDataSN = df.groupby("generation", as_index = False)["suicides_no"].mean().sort_values(by="suicides_no",ascending = False)
plt.figure(figsize=(8,5))
sns.barplot(x = "generation",
            y = "suicides_no",
            data = genDataSN)
plt.xlabel('Generation')
plt.ylabel('Number of Suicide')
plt.title('Suicide Numbers by Generations')
plt.show()

# %% [markdown]
# * We can clearly see that Boomers genration has heighest number of sucide rates.

# %% [markdown]
# # Conclusions
# #### 1. There was a decrease in suicides toward the 80’s. This could be due to awareness of suicide & mental health in the 80s, as well as improved recognition of those at risk. But shortly after that their is a rise suicides that we are seeing.
# #### 2. Russian levels of alcohol consumption plays an immense role in it’s large suicide count, but their is a lack of data to support this due to Soviet secrecy.
# #### 3. The data illustrates that middle aged adults, between the ages of 30 through 60, have the highest suicide count. While elderly and adolescents have about half the amount as middle aged adults.
# #### 4. Suicide is one of the leading causes of death among all Americans adults. Data show alarming differences in suicide for different sexes. It’s evident that males are more inclined to suicide, than females. In addition, Mental health is a major predictor for suicide.
